# %%
Project = '/Users/daehwa/Library/CloudStorage/OneDrive-Personal/Junlab/Projects/Adipocyte'
from IPython.display import display
import pandas as pd
import numpy as np
import gseapy as gp
import csv
import pickle

# %%
RD = pd.read_csv(f'{Project}/Results/Tables/CPM_RD_calculation/v20221217/adi_RD.tsv', sep='\t').drop(columns='gene_name')
RD.iloc[:,1:] = np.log2(RD.iloc[:,1:])

display(RD)
# Out:
#                   gene_id      RD0a      RD0b      RD0c      RD4a      RD4b  \
# 0      ENSMUSG00000033845  0.384560  0.093573  0.176662 -0.286443  0.024544
# 1      ENSMUSG00000025903 -4.670646 -4.631477 -4.298782 -4.865560 -4.168386
# 2      ENSMUSG00000033813 -1.407916 -1.127111 -1.049101 -1.416102 -0.725863
# 3      ENSMUSG00000033793  1.703974  1.563437  1.458909  1.767617  1.910727
# 4      ENSMUSG00000025907  2.355895  3.285892  2.964592  2.521603  3.628401
# ...                   ...       ...       ...       ...       ...       ...
# 11805  ENSMUSG00000064360 -1.190822 -0.264001  1.559481 -1.171672  0.808968
# 11806  ENSMUSG00000064363 -3.459829 -3.415427 -3.128950 -5.300114 -3.597688
# 11807  ENSMUSG00000064367 -2.007124 -2.000537 -1.978983 -2.636981 -1.802296
# 11808  ENSMUSG00000064368 -0.916545 -1.255298 -1.037710 -1.818190 -1.401082
# 11809  ENSMUSG00000064370 -2.769122 -2.961960 -2.832511 -4.419420 -3.308955
#
#            RD4c      RD8a      RD8b      RD8c
# 0     -0.016629  0.042769 -0.347544 -0.186994
# 1     -4.135296 -5.135595 -4.469899 -4.633928
# 2     -0.987097 -1.239836 -0.961624 -0.813096
# 3      1.857605  1.788015  1.926528  1.863422
# 4      2.722776  2.120911  2.662165  2.845057
# ...         ...       ...       ...       ...
# 11805 -0.215973 -3.156482 -2.881273 -1.078799
# 11806 -4.175016 -5.224020 -4.328138 -4.403538
# 11807 -2.803462 -2.833428 -2.371502 -2.489688
# 11808 -1.817293 -1.631776 -1.140065 -1.393552
# 11809 -3.574739 -4.491994 -3.963158 -3.999716
#
# [11810 rows x 10 columns]

# %%
CHIP = pd.read_csv('/Users/daehwa/Library/CloudStorage/OneDrive-Personal/Junlab/Data_Library/GSEA/chip/Mouse_Ensembl_Gene_ID_MSigDB.v2023.2.Mm.chip', sep='\t', usecols=['Probe Set ID','Gene Symbol']).rename(columns={'Probe Set ID':'gene_id'})
display(CHIP)
# Out:
#                   gene_id Gene Symbol
# 0      ENSMUSG00000000001       Gnai3
# 1      ENSMUSG00000000003        Pbsn
# 2      ENSMUSG00000000028       Cdc45
# 3      ENSMUSG00000000031         H19
# 4      ENSMUSG00000000037       Scml2
# ...                   ...         ...
# 43620  ENSMUSG00002076937     Gm25820
# 43621  ENSMUSG00002076971    Snord100
# 43622  ENSMUSG00002076975     Gm23823
# 43623  ENSMUSG00002076989     Gm23510
# 43624  ENSMUSG00002076990     Gm22711
#
# [43625 rows x 2 columns]

# %%
RD_gct = pd.merge(CHIP, RD,on='gene_id', how='right')
RD_gct = RD_gct.sort_values('gene_id').drop_duplicates(subset='Gene Symbol').set_index('Gene Symbol').drop(columns='gene_id')

display(RD_gct)
# Out:
#                  RD0a      RD0b      RD0c      RD4a      RD4b      RD4c  \
# Gene Symbol
# Gnai3        1.273772  1.813141  1.492428  2.013561  2.055045  1.848073
# Cdc45        0.793407  0.980629  1.239551  0.615844  0.880220  0.821295
# Narf         0.100232 -0.021815 -0.137934  0.330452  0.261968  0.253551
# Cav2         0.532570  1.364731  0.908902  1.646404  1.970102  1.882976
# Klf6         0.551694  0.829447  0.671219  1.356006  1.276334  1.440677
# ...               ...       ...       ...       ...       ...       ...
# Lin54        0.522127  0.817545  0.582319  0.917551  1.342251  0.821970
# Ahnak2       1.078441  1.247823  1.305632  1.305619  1.541078  1.106656
# Rps6ka4     -0.834333 -1.016649 -0.944602 -0.582871 -1.020517 -0.829365
# Arvcf        0.670896  0.152394  0.210366  0.458434 -0.165845  0.007636
# Klhl17       0.184403 -0.258225  0.119828  0.287348  0.231540 -0.058550
#
#                  RD8a      RD8b      RD8c
# Gene Symbol
# Gnai3        1.210777  2.193114  1.875994
# Cdc45        0.688324  1.298541  0.978301
# Narf         0.624470  0.661276  0.373920
# Cav2         1.288946  2.630021  2.026957
# Klf6         0.745721  1.428446  1.380510
# ...               ...       ...       ...
# Lin54        0.455156  1.654602  1.714635
# Ahnak2       0.952320  0.844563  0.925181
# Rps6ka4     -0.616872 -0.983338 -1.160086
# Arvcf        0.141306  0.150614  0.157064
# Klhl17       0.573680  0.465073  0.030427
#
# [11808 rows x 9 columns]

# %%
reps = ['a','b','c']

S2N_rnks = {}
for day in ['4','8']:
    S2N_rnks[day] = pd.DataFrame((RD_gct[[f'RD{day}{rep}' for rep in reps]].mean(axis=1) - RD_gct[[f'RD0{rep}' for rep in reps]].mean(axis=1)) / (RD_gct[[f'RD{day}{rep}' for rep in reps]].std(axis=1) + RD_gct[[f'RD0{rep}' for rep in reps]].std(axis=1))).sort_values(0, ascending=False)
display(S2N_rnks['8'])
# Out:
#                      0
# Gene Symbol
# Pkd2l2       24.399498
# Cdc42bpb     13.686618
# Me1          13.213630
# Gtpbp8       12.017863
# F2rl1        11.691288
# ...                ...
# Hcar2       -10.545614
# Rbm15b      -12.124114
# Cidec       -12.477998
# Rpl21       -13.609581
# Kbtbd11     -16.089524
#
# [11808 rows x 1 columns]

# %%
def Prerank(rnk, gmt_f, threads):
    
    pre_res = gp.prerank(rnk=rnk,
                        gene_sets=gmt_f,
                        threads=threads,
                        min_size=15,
                        max_size=500,
                        permutation_num=3000, # reduce number to speed up testing
                        outdir=None, # don't write to disk
                        seed=6,
                        verbose=True, # see what's going on behind the scenes
                        )
    
    return pre_res

# %%
# GSEA
threads = 4
gmt_f = '/Users/daehwa/Library/CloudStorage/OneDrive-Personal/Junlab/Data_Library/GSEA/gmt/m5.go.cc.v2023.1.Mm.symbols.gmt'

gsea_results = {}
for comp in S2N_rnks:
    rnk = S2N_rnks[comp]
    gsea_results[comp] = Prerank(rnk, gmt_f, threads)

gsea_table = {}
for comp in S2N_rnks:
    gsea_table[comp] = gsea_results[comp].res2d
    gsea_table[comp]['N'] = len(S2N_rnks[comp])
# Out:
# 2024-02-08 12:57:54,269 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2024-02-08 12:57:54,278 [INFO] Parsing data files for GSEA.............................
# 2024-02-08 12:57:54,308 [INFO] 0600 gene_sets have been filtered out when max_size=500 and min_size=15
# 2024-02-08 12:57:54,308 [INFO] 0428 gene_sets used for further statistical testing.....
# 2024-02-08 12:57:54,309 [INFO] Start to run GSEA...Might take a while..................
# 2024-02-08 12:58:08,208 [INFO] Congratulations. GSEApy runs successfully................
#
# 2024-02-08 12:58:08,229 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2024-02-08 12:58:08,233 [INFO] Parsing data files for GSEA.............................
# 2024-02-08 12:58:08,256 [INFO] 0600 gene_sets have been filtered out when max_size=500 and min_size=15
# 2024-02-08 12:58:08,257 [INFO] 0428 gene_sets used for further statistical testing.....
# 2024-02-08 12:58:08,257 [INFO] Start to run GSEA...Might take a while..................
# 2024-02-08 12:58:21,889 [INFO] Congratulations. GSEApy runs successfully................

# %%
# Save
with open("adi_logRD_temporal_GOCC.pickle","wb") as fw:
    pickle.dump(gsea_table, fw)

with open("adi_logRD_temporal_GOCC_raw.pickle","wb") as fw:
    pickle.dump(gsea_results, fw)

# %%
tmp = gsea_table['4'].sort_values('NES', ascending=True)
display(tmp[tmp['FDR q-val']<0.01])
# Out:
#       Name                                               Term        ES  \
# 0  prerank  GOCC_INNER_MITOCHONDRIAL_MEMBRANE_PROTEIN_COMPLEX  -0.68544
# 1  prerank                                   GOCC_RESPIRASOME -0.716673
# 2  prerank                    GOCC_NADH_DEHYDROGENASE_COMPLEX  -0.76749
# 3  prerank      GOCC_MITOCHONDRIAL_PROTEIN_CONTAINING_COMPLEX -0.551312
# 4  prerank                           GOCC_ORGANELLAR_RIBOSOME -0.599966
# 5  prerank                            GOCC_CYTOCHROME_COMPLEX  -0.68485
# 6  prerank         GOCC_MITOCHONDRIAL_LARGE_RIBOSOMAL_SUBUNIT -0.607182
# 7  prerank                  GOCC_RESPIRATORY_CHAIN_COMPLEX_IV -0.697658
#
#         NES NOM p-val FDR q-val FWER p-val    Tag %  Gene %  \
# 0 -2.887136       0.0       0.0        0.0   82/141  15.28%
# 1 -2.822744       0.0       0.0        0.0    59/89  16.50%
# 2 -2.688557       0.0       0.0        0.0    35/48  16.50%
# 3  -2.53272       0.0       0.0        0.0  151/285  20.14%
# 4 -2.349957       0.0       0.0        0.0    48/90  19.46%
# 5 -2.250973       0.0  0.000394   0.002667    20/36  10.77%
# 6 -2.207763       0.0  0.000549   0.004333    31/57  19.46%
# 7 -2.114713       0.0  0.002734      0.023    15/25  10.77%
#
#                                           Lead_genes      N
# 0  Atp5md;Cox8b;Atp5g1;Smdt1;Uqcr11;mt-Co3;Romo1;...  11808
# 1  Cox8b;Uqcr11;mt-Co3;Uqcc3;Ndufs7;mt-Nd1;Uqcrq;...  11808
# 2  Ndufs7;mt-Nd1;Ndufb7;Ndufb8;Ndufs6;Ndufa13;Ndu...  11808
# 3  Mrpl54;Atp5md;Cox8b;Atp5g1;Smdt1;Mrpl18;Uqcr11...  11808
# 4  Mrpl54;Mrpl18;Mrpl2;Mrpl41;Mrpl57;Mrpl3;Mrps24...  11808
# 5  Cox8b;Uqcr11;mt-Co3;Uqcc3;Uqcrq;Cox8a;Cox6c;Nd...  11808
# 6  Mrpl54;Mrpl18;Mrpl2;Mrpl41;Mrpl57;Mrpl3;Mrpl14...  11808
# 7  Cox8b;mt-Co3;Cox8a;Cox6c;Ndufa4;mt-Co2;Coa6;Co...  11808

# %%
tmp = gsea_table['8'].sort_values('NES', ascending=True)
display(tmp[tmp['FDR q-val']<0.01])
# Out:
#        Name                                               Term        ES  \
# 0   prerank  GOCC_INNER_MITOCHONDRIAL_MEMBRANE_PROTEIN_COMPLEX  -0.61053
# 1   prerank                                   GOCC_RESPIRASOME -0.642963
# 2   prerank                    GOCC_NADH_DEHYDROGENASE_COMPLEX -0.701978
# 3   prerank      GOCC_MITOCHONDRIAL_PROTEIN_CONTAINING_COMPLEX  -0.43588
# 4   prerank       GOCC_SMALL_NUCLEAR_RIBONUCLEOPROTEIN_COMPLEX -0.533705
# 5   prerank             GOCC_CYTOSOLIC_SMALL_RIBOSOMAL_SUBUNIT -0.586864
# 6   prerank                             GOCC_RIBOSOMAL_SUBUNIT -0.445772
# 7   prerank                            GOCC_CYTOCHROME_COMPLEX -0.587283
# 8   prerank                            GOCC_CYTOSOLIC_RIBOSOME -0.485358
# 9   prerank                           GOCC_MHC_PROTEIN_COMPLEX -0.726362
# 10  prerank                       GOCC_LARGE_RIBOSOMAL_SUBUNIT -0.468294
#
#          NES NOM p-val FDR q-val FWER p-val    Tag %  Gene %  \
# 0  -2.651371       0.0       0.0        0.0   86/141  19.64%
# 1  -2.592375       0.0       0.0        0.0    59/89  19.74%
# 2  -2.517026       0.0       0.0        0.0    34/48  16.84%
# 3   -2.07318       0.0  0.005498   0.016333  134/285  21.18%
# 4  -2.035885  0.001093  0.007301      0.026    25/66  18.95%
# 5  -2.025699  0.000958  0.006524      0.028    20/38  25.27%
# 6   -2.00986       0.0  0.007163   0.035333   88/174  28.98%
# 7  -1.997921       0.0  0.007312      0.041    22/36  18.40%
# 8  -1.994253       0.0  0.006695   0.042333    46/88  28.30%
# 9  -1.958728  0.000842  0.009676   0.067333     8/15  14.06%
# 10 -1.958354       0.0  0.008796   0.067333   64/106  31.02%
#
#                                            Lead_genes      N
# 0   Chchd3;Atp5g1;Cox8b;Uqcrb;mt-Cytb;Ndufa4;Timm1...  11808
# 1   Cox8b;Uqcrb;mt-Cytb;Ndufa4;Ndufb7;Uqcc3;Cox7b;...  11808
# 2   Ndufa4;Ndufb7;Ndufb4;mt-Nd5;Ndufa13;Ndufs6;mt-...  11808
# 3   Chchd3;Atp5g1;Cox8b;Uqcrb;mt-Cytb;Ndufa4;Mrpl3...  11808
# 4   Prpf6;Prpf40b;Lsm7;Lsm2;Sf3b2;Snrpb2;Sart1;Lsm...  11808
# 5   Ubb;Rps3a1;Rps27l;Eif2d;Rps26;Rps20;Rps5;Rps16...  11808
# 6   Rpl21;Rpl7a;Ubb;Mrpl33;Rpl27a;Mrpl3;Rpl10;Mrpl...  11808
# 7   Cox8b;Uqcrb;mt-Cytb;Ndufa4;Uqcc3;Cox7b;Uqcrq;U...  11808
# 8   Rpl21;Rpl7a;Ubb;Rpl27a;Rpl10;Rps3a1;Rpl6;Rpl23...  11808
# 9   H2-Q10;B2m;H2-DMb1;H2-Ab1;H2-Q7;H2-K1;H2-Q4;H2...  11808
# 10  Rpl21;Rpl7a;Mrpl33;Rpl27a;Mrpl3;Rpl10;Mrpl57;M...  11808
