# %%
Project = '/Users/daehwa/Library/CloudStorage/OneDrive-Personal/Junlab/Projects/Adipocyte'

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

plt.rcParams.update(plt.rcParamsDefault)

mpl.rcParams['font.sans-serif'] = "Arial"
mpl.rcParams['font.family'] = "sans-serif"

plt.rcParams['ps.useafm']=True
plt.rcParams['pdf.fonttype']=42

plt.rc('font', size=7)          # controls default text sizes
plt.rc('axes', titlesize=8)     # fontsize of the axes title
plt.rc('axes', labelsize=8)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=6)    # fontsize of the tick labels
plt.rc('ytick', labelsize=6)    # fontsize of the tick labels
plt.rc('legend', fontsize=6)    # legend fontsize
suptitlesize = 8

plt.rc('axes', axisbelow=True) #push axes to back
mpl.rcParams['axes.linewidth'] = 0.5

# %%
Metadata = pd.read_csv(f'{Project}/Results/Other_papers/Emont_etal.2022.Nature/scRNAseq/Emont_UMAP_metadata1.tsv', sep='\t')
display(Metadata)
display(set(Metadata['cell_type']))
# Out:
#            UMAP_1     UMAP_2                       cell_ID  cell_type  Adipoq  \
# 0       -9.542621  -3.414303  Mm_ING_16-1_TCGCACTTCCAAGCTA  Adipocyte       0
# 1       -9.658376  -3.045981  Mm_ING_16-1_CCTATCGTCATTCACT  Adipocyte       4
# 2      -10.773140  -2.729421  Mm_ING_16-1_GCCATTCCATGCACTA  Adipocyte       2
# 3       -9.749936  -3.078376  Mm_ING_16-1_AAGTTCGCACGGTCTG  Adipocyte       0
# 4      -11.210072  -2.699991  Mm_ING_16-1_GACACGCCAACAACAA  Adipocyte       2
# ...           ...        ...                           ...        ...     ...
# 190694   4.532373  10.897151  Mm_ING_11-1_GGTGAAGCAATACCCA       ASPC       0
# 190695   5.225076   9.215297  Mm_ING_11-1_CCCGAAGAGGTGGCTA       ASPC       0
# 190696   4.642291  10.113908  Mm_ING_11-1_ACTGATGAGTTCCAGT       ASPC       0
# 190697   5.259043   9.444798  Mm_ING_11-1_GATAGAAAGAGTCCGA       ASPC       0
# 190698   4.735714  10.087993  Mm_ING_11-1_TTACCATGTCTAACTG       ASPC       0
#
# ...

# %%
custom_order = ['Endothelial', 'Epithelial', 'Immune cells', 'Mesothelial', 'Smooth muscle'] + ['ASPC', 'Adipocyte']

color_order = {'ASPC'          : '#FFCC99', 
               'Adipocyte'     : '#E69F00', 
               'Endothelial'   : '#AAAAAA', 
               'Epithelial'    : '#AAAAAA', 
               'Immune cells'  : '#AAAAAA', 
               'Mesothelial'   : '#AAAAAA', 
               'Smooth muscle' : '#AAAAAA'}

# %%
fig = plt.figure(figsize=(1.8, 1.8), dpi=150)
ax = plt.axes([0,0,1,1])

for order in custom_order:
    tmp_data = Metadata[Metadata['cell_type']==order]
    ax.scatter(tmp_data['UMAP_1'], tmp_data['UMAP_2'], label=order,
                s=0.1, alpha=1, lw=0, color=color_order[order], rasterized=True)

ax.set_title('')
ax.set_xlabel('UMAP 1', labelpad=2)
ax.set_ylabel('UMAP 2', labelpad=2)
ax.set_xticks([])
ax.set_yticks([])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
# ax.spines['bottom'].set_visible(False)
# ax.spines['left'].set_visible(False)

# lgnd = plt.legend(bbox_to_anchor=(1,1), loc="upper left")
# for i in range(len(custom_order[filt])): lgnd.legendHandles[i]._sizes = [70]

# plt.savefig('Emont_UMAP_type1.pdf', bbox_inches='tight')
plt.show()

# %%
custom_order = ['Smooth muscle', 'Endothelial', 'Mesothelial', 'Epithelial', 'Immune cells'] + ['ASPC', 'Adipocyte']

color_order = {'ASPC'          : '#DDDDDD', 
               'Adipocyte'     : '#FFCC88', 
               'Endothelial'   : '#359B73', 
               'Mesothelial'   : '#3DB7E9', 
               'Epithelial'    : '#2271B2', 
               'Immune cells'  : '#AA0DB4', 
               'Smooth muscle' : '#F8071D'}

# %%
fig = plt.figure(figsize=(1.5, 1.5), dpi=300)
ax = plt.axes([0,0,1,1])

for order in custom_order:
    tmp_data = Metadata[Metadata['cell_type']==order]
    ax.scatter(tmp_data['UMAP_1'], tmp_data['UMAP_2'], label=order,
                s=0.1, alpha=1, lw=0, color=color_order[order], rasterized=True)

ax.set_title('')
ax.set_xlabel('UMAP 1', labelpad=1, fontsize=7)
ax.set_ylabel('UMAP 2', labelpad=1, fontsize=7)
ax.set_xticks([])
ax.set_yticks([])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
# ax.spines['bottom'].set_visible(False)
# ax.spines['left'].set_visible(False)

lgnd = plt.legend(bbox_to_anchor=(1,1), loc="upper left")
for i in range(len(custom_order)): lgnd.legendHandles[i]._sizes = [20]

plt.savefig('Emont_UMAP_type2.pdf', bbox_inches='tight')
plt.show()
# Out:
# /var/folders/ct/z73cq4_j2g5612tltg_pmxxc0000gn/T/ipykernel_86083/1638589822.py:21: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for i in range(len(custom_order)): lgnd.legendHandles[i]._sizes = [20]
