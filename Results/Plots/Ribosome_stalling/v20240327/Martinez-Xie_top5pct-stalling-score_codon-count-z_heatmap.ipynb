# %%
Project = '/Users/daehwa/Library/CloudStorage/OneDrive-Personal/Junlab/Projects/Adipocyte'

import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

plt.rcParams.update(plt.rcParamsDefault)

mpl.rcParams['font.sans-serif'] = "Arial"
mpl.rcParams['font.family'] = "sans-serif"

plt.rcParams['ps.useafm']=True
plt.rcParams['pdf.fonttype']=42

plt.rc('font', size=7)          # controls default text sizes
plt.rc('axes', titlesize=7)     # fontsize of the axes title
plt.rc('axes', labelsize=6)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=6)    # fontsize of the tick labels
plt.rc('ytick', labelsize=6)    # fontsize of the tick labels
plt.rc('legend', fontsize=6)    # legend fontsize
suptitlesize = 7

plt.rc('axes', axisbelow=True) #push axes to back
mpl.rcParams['axes.linewidth'] = 0.3

# %%
stalling_score_dict = {}

paths = {
    'Ours' : f'{Project}/Results/Tables/Ribosome_stalling/v20230730/adi_stall-score.df.pickle',
    'Martinez' : f'{Project}/Results/Other_papers/Martinez_etal.2023.Cell_Metabolism/Tables/Ribosome_stalling/v20230827/Martinez_stall-score.df.pickle',
    'Xie' : f'{Project}/Results/Other_papers/Xie_etal.2023.Diabetes/Tables/Ribosome_stalling/v20230902/Xie_stall-score.df.pickle'
}

for dataset in paths:
    with open(paths[dataset],"rb") as fr: stalling_score_dict[dataset] = pickle.load(fr)
    stalling_score_dict[dataset]['AA_codon'] = stalling_score_dict[dataset]['aa-asite']+' '+stalling_score_dict[dataset]['codon-asite']
    stalling_score_dict[dataset] = stalling_score_dict[dataset].replace(0, np.nan).dropna()

    display(stalling_score_dict[dataset])
# Out:
#                 transcript_id  asite  reltostart-asite codon-asite aa-asite  \
# 6        ENSMUST00000000001.5    195                54         AUC        I
# 7        ENSMUST00000000001.5    198                57         GAC        D
# 9        ENSMUST00000000001.5    204                63         AAC        N
# 10       ENSMUST00000000001.5    213                72         GAG        E
# 13       ENSMUST00000000001.5    228                87         GCG        A
# ...                       ...    ...               ...         ...      ...
# 1024950  ENSMUST00000239525.1  10109              9978         GAG        E
# 1024957  ENSMUST00000239525.1  10139             10008         GAG        E
# 1024966  ENSMUST00000239525.1  10184             10053         AAA        K
# 1025016  ENSMUST00000239525.1  10442             10311         GAG        E
# 1025041  ENSMUST00000239525.1  10583             10452         GAA        E
#
#                D0a        D0b       D0c        D4a       D4b        D4c  \
# 6         1.876404   1.591739  5.703044   2.955752  0.824691   1.796907
# 7         1.876404   1.591739  0.991834   0.268705  1.237037   0.673840
# 9         3.987360   1.326450  4.711210   5.642800  0.824691   2.470746
# 10        3.049157   2.652899  3.471418   2.149638  2.474074   2.695360
# 13        1.641854   1.326450  4.711210   0.806114  0.824691   2.695360
# ...            ...        ...       ...        ...       ...        ...
# 1024950   7.105894  12.158446  6.512629   5.410881  3.658754   4.345818
# 1024957  15.544144   9.210944  7.598067  13.527202  9.146886  14.775780
# 1024966   2.664710   2.210627  3.527674  13.527202  8.232198   5.214981
# 1025016   1.776474   2.579064  0.542719   3.607254  0.304896   0.869164
# 1025041   2.220592   3.684378  5.155831   6.312694  5.183236   5.214981
#
#                D8a        D8b        D8c AA_codon
# 6         3.290640   1.739583   2.312308    I AUC
# 7         0.658128   1.159722   0.770769    D GAC
# 9         0.658128   0.579861   1.027692    N AAC
# 10        1.974384   2.899306   1.798462    E GAG
# 13        2.303448   2.899306   5.652308    A GCG
# ...            ...        ...        ...      ...
# 1024950   3.622268   7.712703   1.497849    E GAG
# 1024957   5.433403   5.141802   1.497849    E GAG
# 1024966  16.300208  10.283604  23.965577    K AAA
# 1025016   3.622268  10.283604   1.497849    E GAG
# 1025041   7.244537  15.425406   2.995697    E GAA
#
# [357284 rows x 15 columns]
#                transcript_id  asite  reltostart-asite codon-asite aa-asite  \
# 3       ENSMUST00000000001.5    207                66         UUG        L
# 5       ENSMUST00000000001.5    237                96         GAA        E
# 12      ENSMUST00000000001.5    297               156         AUG        M
# 14      ENSMUST00000000001.5    414               273         AAG        K
# 17      ENSMUST00000000001.5    429               288         GAA        E
# ...                      ...    ...               ...         ...      ...
# 220720  ENSMUST00000239497.2   1603              1329         AAA        K
# 220721  ENSMUST00000239497.2   1606              1332         AUU        I
# 220722  ENSMUST00000239497.2   1615              1341         GAG        E
# 220723  ENSMUST00000239497.2   1627              1353         UUA        L
# 220725  ENSMUST00000239497.2   1633              1359         GCU        A
#
#               BGa        BGb        BRa        BRb        WHa        WHb  \
# 3        9.364486   7.367647   5.087032   2.380048   7.275934   4.358891
# 5        7.803738   3.683824   0.872063   2.380048   0.461964   2.179445
# 12       3.121495   4.502451   2.325500   8.726841   4.619640   7.628059
# 14       4.682243   0.818627   3.197563   0.793349   1.039419   1.634584
# 17      29.654206  15.963235  13.516971  15.073634  10.740664  14.711256
# ...           ...        ...        ...        ...        ...        ...
# 220720   6.211604   8.412379   2.175197   7.266160   0.729556   6.798042
# 220721   7.764505   4.023312   1.023622   6.228137   0.607964   8.438949
# 220722   1.552901   1.097267   5.246063   0.346008   3.161411   2.578568
# 220723   3.105802   2.560289   1.023622   2.076046   0.729556   0.937661
# 220725  31.058020  11.704180   4.734252   7.612167   6.444415   6.329212
#
#        AA_codon
# 3         L UUG
# 5         E GAA
# 12        M AUG
# 14        K AAG
# 17        E GAA
# ...         ...
# 220720    K AAA
# 220721    I AUU
# 220722    E GAG
# 220723    L UUA
# 220725    A GCU
#
# [113236 rows x 12 columns]
#               transcript_id  asite  reltostart-asite codon-asite aa-asite  \
# 3      ENSMUST00000000058.7    269                93         AAG        K
# 4      ENSMUST00000000058.7    272                96         UAU        Y
# 5      ENSMUST00000000058.7    275                99         GUU        V
# 6      ENSMUST00000000058.7    284               108         AGU        S
# 7      ENSMUST00000000058.7    296               120         GAU        D
# ...                     ...    ...               ...         ...      ...
# 92147  ENSMUST00000239497.2   1606              1332         AUU        I
# 92148  ENSMUST00000239497.2   1612              1338         ACA        T
# 92149  ENSMUST00000239497.2   1615              1341         GAG        E
# 92150  ENSMUST00000239497.2   1618              1344         AAG        K
# 92151  ENSMUST00000239497.2   1621              1347         GAC        D
#
#        cold_iWATa  cold_iWATb AA_codon
# 3       13.181435   20.439394    K AAG
# 4        1.797468    4.303030    Y UAU
# 5        5.991561   10.757576    V GUU
# 6        1.797468    1.075758    S AGU
# 7        1.797468    1.075758    D GAU
# ...           ...         ...      ...
# 92147    3.513514    4.527363    I AUU
# 92148    3.513514    2.263682    T ACA
# 92149   10.540541    2.263682    E GAG
# 92150   15.810811   18.109453    K AAG
# 92151   35.135135   36.218905    D GAC
#
# [56533 rows x 8 columns]

# %%
plot_data_dict = {}

Cond_groups = {
    'Martinez' : ['BG','BR','WH'],
    'Xie' : ['cold_iWAT']
}

for dataset in Cond_groups:
    tmp_df = pd.DataFrame(columns=list(set(stalling_score_dict[dataset]['AA_codon'])))

    for SP in stalling_score_dict[dataset].iloc[:,5:-1]:
        tmp = stalling_score_dict[dataset].sort_values(SP, ascending=False)[:(len(stalling_score_dict[dataset])//100)*5]
        tmp_df = pd.concat([tmp_df, pd.DataFrame(tmp.value_counts('AA_codon')).T.rename(index={0:SP})])

    tmp_df = tmp_df.drop(columns=[colname for colname in tmp_df.columns if colname.startswith('*')]).T.replace(np.nan,0).sort_index()

    for Cd in Cond_groups[dataset]:
        tmp_df[Cd] = tmp_df[[colname for colname in tmp_df.columns if colname.startswith(Cd)]].mean(axis=1)
    tmp_df = tmp_df[Cond_groups[dataset]]

    tmp_df = tmp_df.rename(columns={'BG':'Beige adipocyte', 'BR':'Brown adipocyte', 'WH':'White adipocyte',
                                    'cold_iWAT':'Cold-treated iWAT'})

    display(tmp_df)
    plot_data_dict[dataset] = tmp_df
# Out:
#        Beige adipocyte  Brown adipocyte  White adipocyte
# A GCA             48.5             67.5             76.0
# A GCC            101.5             91.5            100.5
# A GCG             47.5             38.5             49.0
# A GCU            172.0            136.5            137.5
# C UGC             23.0             27.5             29.5
# ...                ...              ...              ...
# V GUG            119.0            115.5             77.5
# V GUU             51.5             47.5             48.0
# W UGG            108.5            103.5             91.0
# Y UAC             41.5             57.0             64.5
# Y UAU             54.0             69.5             61.5
#
# [61 rows x 3 columns]
#        Cold-treated iWAT
# A GCA               25.0
# A GCC               21.5
# A GCG                5.0
# A GCU               19.5
# C UGC               13.0
# ...                  ...
# V GUG               48.5
# V GUU               36.0
# W UGG               32.5
# Y UAC               54.5
# Y UAU               27.5
#
# [61 rows x 1 columns]

# %%
tmp = pd.merge(plot_data_dict['Martinez'], plot_data_dict['Xie'], left_index=True, right_index=True)
tmp = tmp.sort_values('Beige adipocyte', ascending=False)

P_data = {}
P_data['Martinez'] = tmp.iloc[:,:3]
P_data['Xie'] = tmp[['Cold-treated iWAT']]

display(P_data)
# Out:
# {'Martinez':        Beige adipocyte  Brown adipocyte  White adipocyte
#  E GAA            978.0            782.5            772.5
#  E GAG            420.5            376.0            332.0
#  D GAC            326.0            404.5            552.5
#  K AAG            307.5            277.0            271.0
#  D GAU            295.5            329.5            428.0
#  ...                ...              ...              ...
#  R CGU             21.5             18.5             18.0
#  S UCA             20.0             30.0             38.5
#  H CAC             17.0             21.0             22.5
#  Q CAA             11.5             13.5             17.5
#  H CAU             10.5             15.5             19.0
#
#  [61 rows x 3 columns],
#  'Xie':        Cold-treated iWAT
#  E GAA              215.5
#  E GAG              175.0
#  D GAC              185.0
#  K AAG              161.0
#  D GAU              150.0
#  ...                  ...
#  R CGU                7.0
#  S UCA               23.0
#  H CAC               40.5
#  Q CAA               11.0
#  H CAU               14.0
#
#  [61 rows x 1 columns]}

# %% [markdown]
# # Plot

# %%
sF = 1 # Size factor
wgap = 0.03
hgap = 0
nrow, ncol = 1, 2

width_ratios = [0.33, 0.11]
height_ratios = [2]

fs_w = sum(np.array(width_ratios)*sF) + (ncol-1)*wgap*sF
fs_h = sum(np.array(height_ratios)*sF) + (nrow-1)*hgap*sF

#
fig = plt.figure(figsize=( fs_w, fs_h ), dpi=300)
grid = plt.GridSpec(nrow, ncol,
                    width_ratios=width_ratios,
                    height_ratios=height_ratios,
                    wspace=wgap/np.average(width_ratios), 
                    hspace=hgap/np.average(height_ratios),
                    left=0, right=1, bottom=0, top=1)

row = 0
col = 0
for dataset in P_data:

    ax = fig.add_subplot(grid[row,col])

    heat = ax.imshow(P_data[dataset], 
                 cmap='Purples', vmin=0, vmax={'Martinez':1000, 'Xie':230}[dataset], 
                 interpolation='none', aspect='auto', rasterized=True)
    
    ax.set_xticks(range(len(P_data[dataset].columns)))
    ax.set_yticks([])
    ax.set_xticklabels(P_data[dataset].columns, rotation=-90)
    ax.tick_params(length=0)

    ax.set_xlabel('')
    ax.set_ylabel('')

    col+=1

plt.savefig('Martinez-Xie_top5pct-stalling-score_codon-count-z_heatmap.pdf', bbox_inches='tight')
plt.show()
plt.close()
